# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("/content/India_Economy_Analytics_Dataset_by chandan goswami.csv")
df.head()
# Out:
#    year           state  gdp_per_capita  literacy_rate  female_literacy_rate  \
# 0  2011  Andhra Pradesh          240385            NaN             89.950131
# 1  2012  Andhra Pradesh          223345      97.690704             60.245726
# 2  2013  Andhra Pradesh          111225      76.896740             71.940358
# 3  2014  Andhra Pradesh          257312      74.307271             93.248441
# 4  2015  Andhra Pradesh          151387      72.002474             77.159622
#
#    poverty_rate  unemployment_rate  internet_penetration  \
# 0           NaN           9.309082             31.431614
# 1     31.942756           9.720904             47.082310
# 2     26.960099           9.241288             42.786799
# 3     19.341437           8.262790             18.678242
# 4      7.716484           5.115394             15.557005
#
#    urban_population_pct  life_expectancy
# 0             68.980663        71.777263
# 1             47.236635        75.289484
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   year                  156 non-null    int64
#  1   state                 156 non-null    object
#  2   gdp_per_capita        156 non-null    int64
#  3   literacy_rate         145 non-null    float64
#  4   female_literacy_rate  145 non-null    float64
#  5   poverty_rate          145 non-null    float64
#  6   unemployment_rate     145 non-null    float64
#  7   internet_penetration  145 non-null    float64
#  8   urban_population_pct  145 non-null    float64
#  9   life_expectancy       145 non-null    float64
# dtypes: float64(7), int64(2), object(1)
# memory usage: 12.3+ KB

# %%
df.isnull().sum()
# Out:
# year                     0
# state                    0
# gdp_per_capita           0
# literacy_rate           11
# female_literacy_rate    11
# poverty_rate            11
# unemployment_rate       11
# internet_penetration    11
# urban_population_pct    11
# life_expectancy         11
# dtype: int64

# %%
df['literacy_rate']=df['literacy_rate'].fillna(df['literacy_rate'].mean())
df['female_literacy_rate']=df['female_literacy_rate'].fillna(df['female_literacy_rate'].mean())
df['poverty_rate']=df['poverty_rate'].fillna(df['poverty_rate'].mean())
df['unemployment_rate']=df['unemployment_rate'].fillna(df['unemployment_rate'].mean())
df['internet_penetration']=df['internet_penetration'].fillna(df['internet_penetration'].mean())
df['life_expectancy']=df['life_expectancy'].fillna(df['life_expectancy'].mean())
df['urban_population_pct']=df["urban_population_pct"].fillna(df['urban_population_pct'].mean())

# %%
df.isnull().sum()
# Out:
# year                    0
# state                   0
# gdp_per_capita          0
# literacy_rate           0
# female_literacy_rate    0
# poverty_rate            0
# unemployment_rate       0
# internet_penetration    0
# urban_population_pct    0
# life_expectancy         0
# dtype: int64

# %%
df.describe()
# Out:
#               year  gdp_per_capita  literacy_rate  female_literacy_rate  \
# count   156.000000      156.000000     156.000000            156.000000
# mean   2017.000000   170127.333333      81.672103             80.079870
# std       3.753708    52419.764963       9.802218              9.986525
# min    2011.000000    82124.000000      65.083685             60.245726
# 25%    2014.000000   121618.000000      73.973518             71.914166
# 50%    2017.000000   169219.500000      81.672103             80.172596
# 75%    2020.000000   209075.750000      90.352103             88.748516
# max    2023.000000   259799.000000      97.914780             95.976182
#
#        poverty_rate  unemployment_rate  internet_penetration  \
# count    156.000000         156.000000            156.000000
# mean      22.580989           7.810043             56.407311
# std       10.281203           2.397816             23.036105
# min        5.107239           3.090349             15.189320
# ...

# %%
df.columns
# Out:
# Index(['year', 'state', 'gdp_per_capita', 'literacy_rate',
#        'female_literacy_rate', 'poverty_rate', 'unemployment_rate',
#        'internet_penetration', 'urban_population_pct', 'life_expectancy'],
#       dtype='object')

# %%
df['year'].unique()
# Out:
# array([2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021,
#        2022, 2023])

# %%
def ext(a):
  if a==2011 or a==2012 or a==2013 or a==2014:
    return "Phase-1"
  elif a==2015 or a==2016 or a==2017 or a==2018 or a==2019:
    return "Phase-2"
  else:
    return "Phase-3"

# %%
df["year_by_phase"]=df['year'].map(ext)

# %%
df["year_by_phase"]
# Out:
# 0      Phase-1
# 1      Phase-1
# 2      Phase-1
# 3      Phase-1
# 4      Phase-2
#         ...
# 151    Phase-2
# 152    Phase-3
# 153    Phase-3
# 154    Phase-3
# 155    Phase-3
# Name: year_by_phase, Length: 156, dtype: object

# %%
df.head(10)
# Out:
#    year           state  gdp_per_capita  literacy_rate  female_literacy_rate  \
# 0  2011  Andhra Pradesh          240385      81.672103             89.950131
# 1  2012  Andhra Pradesh          223345      97.690704             60.245726
# 2  2013  Andhra Pradesh          111225      76.896740             71.940358
# 3  2014  Andhra Pradesh          257312      74.307271             93.248441
# 4  2015  Andhra Pradesh          151387      72.002474             77.159622
# 5  2016  Andhra Pradesh          101987      88.293897             73.592332
# 6  2017  Andhra Pradesh          191014      81.672103             94.857846
# 7  2018  Andhra Pradesh          192277      95.992855             90.149769
# 8  2019  Andhra Pradesh          207017      74.191996             94.939544
# 9  2020  Andhra Pradesh          236589      88.710711             94.487280
#
#    poverty_rate  unemployment_rate  internet_penetration  \
# 0     22.580989           9.309082             31.431614
# ...

# %%
x=df.groupby(["year_by_phase",'state'],as_index=False)["gdp_per_capita"].mean().sort_values(by="gdp_per_capita",ascending=False)
x=x[x['year_by_phase']=='Phase-1']
x
# Out:
#    year_by_phase           state  gdp_per_capita
# 7        Phase-1     Maharashtra       223744.75
# 0        Phase-1  Andhra Pradesh       208066.75
# 6        Phase-1  Madhya Pradesh       200480.25
# 11       Phase-1     West Bengal       193098.75
# 9        Phase-1      Tamil Nadu       186946.25
# 8        Phase-1       Rajasthan       178140.50
# 1        Phase-1           Bihar       174865.50
# 5        Phase-1          Kerala       172515.50
# 2        Phase-1           Delhi       166378.50
# 3        Phase-1         Gujarat       159999.25
# 10       Phase-1   Uttar Pradesh       150021.25
# 4        Phase-1       Karnataka       141647.50

# %%
plt.figure(figsize=(15,8))#phase 1 year 2011 - 2014 state gdp distribution
ax = sns.barplot(x="state",y="gdp_per_capita",data=x, hue="state", palette="viridis", legend=False)
for container in ax.containers:
    ax.bar_label(container)
plt.xticks(rotation=90)
plt.show()

# %%
y=df.groupby(["year_by_phase",'state'],as_index=False)["gdp_per_capita"].mean().sort_values(by="gdp_per_capita",ascending=False)
y=y[y['year_by_phase']=='Phase-2']
y
# Out:
#    year_by_phase           state  gdp_per_capita
# 23       Phase-2     West Bengal        184766.6
# 20       Phase-2       Rajasthan        174633.0
# 19       Phase-2     Maharashtra        172625.8
# 13       Phase-2           Bihar        169734.0
# 12       Phase-2  Andhra Pradesh        168736.4
# 17       Phase-2          Kerala        161585.8
# 16       Phase-2       Karnataka        160585.0
# 22       Phase-2   Uttar Pradesh        159553.6
# 15       Phase-2         Gujarat        159397.2
# 18       Phase-2  Madhya Pradesh        148270.4
# 14       Phase-2           Delhi        143414.8
# 21       Phase-2      Tamil Nadu        138250.0

# %%
plt.figure(figsize=(15,8))#phase 1 year 2015 - 2019 state gdp distribution
ax = sns.barplot(x="state",y="gdp_per_capita",data=y, hue="state", palette="viridis", legend=False)
for container in ax.containers:
    ax.bar_label(container)
plt.xticks(rotation=90)
plt.show()

# %%
z=df.groupby(["year_by_phase",'state'],as_index=False)["gdp_per_capita"].mean().sort_values(by="gdp_per_capita",ascending=False)
z=z[z['year_by_phase']=='Phase-3']
z
# Out:
#    year_by_phase           state  gdp_per_capita
# 26       Phase-3           Delhi       203851.00
# 29       Phase-3          Kerala       202232.75
# 30       Phase-3  Madhya Pradesh       200537.50
# 27       Phase-3         Gujarat       182580.50
# 24       Phase-3  Andhra Pradesh       171448.50
# 25       Phase-3           Bihar       167823.25
# 33       Phase-3      Tamil Nadu       165568.50
# 34       Phase-3   Uttar Pradesh       159921.75
# 35       Phase-3     West Bengal       158137.50
# 31       Phase-3     Maharashtra       148907.50
# 32       Phase-3       Rajasthan       147702.50
# 28       Phase-3       Karnataka       143409.25

# %%
plt.figure(figsize=(15,8))
ax = sns.barplot(x="state",y="gdp_per_capita",data=z, hue="state", palette="viridis", legend=False)
for container in ax.containers:
    ax.bar_label(container)
plt.title('Average GDP per Capita by State (Phase-3: 2020-2023)', fontsize=16)
plt.xlabel('State', fontsize=12)
plt.ylabel('Average GDP per Capita', fontsize=12)
plt.xticks(rotation=45, ha='right', fontsize=10)
plt.yticks(fontsize=10)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
a=df.groupby(["year_by_phase"],as_index=False)["gdp_per_capita"].mean()
a
# Out:
#   year_by_phase  gdp_per_capita
# 0       Phase-1   179658.729167
# 1       Phase-2   161796.050000
# 2       Phase-3   171010.041667

# %%
plt.figure(figsize=(8, 8))
plt.pie(labels=a['year_by_phase'], x=a['gdp_per_capita'], autopct='%1.2f%%', startangle=90)
plt.title('Distribution of Average GDP per Capita Across Phases')
plt.axis('equal')
plt.show()

# %%
b=df.groupby(["year_by_phase",'state'],as_index=False)["gdp_per_capita"].mean()
b.head()
# Out:
#   year_by_phase           state  gdp_per_capita
# 0       Phase-1  Andhra Pradesh       208066.75
# 1       Phase-1           Bihar       174865.50
# 2       Phase-1           Delhi       166378.50
# 3       Phase-1         Gujarat       159999.25
# 4       Phase-1       Karnataka       141647.50

# %%
plt.figure(figsize=(18, 9))
ax = sns.lineplot(data=b, x='state', y='gdp_per_capita', hue='year_by_phase', marker='o', linewidth=2.5)
plt.title('Average GDP per Capita by State Across Different Phases', fontsize=16)
plt.xlabel('State', fontsize=12)
plt.ylabel('Average GDP per Capita', fontsize=12)
plt.xticks(rotation=45, ha='right', fontsize=10)
plt.yticks(fontsize=10)
plt.grid(True, linestyle='--', alpha=0.7)
plt.legend(title='Year Phase', title_fontsize='13', fontsize='11', loc='upper left', bbox_to_anchor=(1, 1))
for line in ax.lines:
    for x_val, y_val in zip(line.get_xdata(), line.get_ydata()):
        state_name = ax.get_xticks()[int(x_val)]
        ax.text(x_val, y_val, f'{y_val:.0f}', color='black', ha='center', va='bottom', fontsize=8)
plt.tight_layout()
plt.show()

# %%
b['gdp_growth_rate'] = b.groupby('state')['gdp_per_capita'].pct_change() * 100
avg_growth_rate = b.groupby('state')['gdp_growth_rate'].mean().sort_values(ascending=False)
display(avg_growth_rate.head())
print("\nBottom Performing States (Average GDP Growth Rate):")
display(avg_growth_rate.tail())
# Out:
# state
# Delhi             14.169378
# Kerala             9.409769
# Gujarat            7.084038
# Madhya Pradesh     4.604406
# Uttar Pradesh      3.292369
# Name: gdp_growth_rate, dtype: float64
# Bottom Performing States (Average GDP Growth Rate):
# state
# Tamil Nadu        -3.144023
# Andhra Pradesh    -8.647728
# Rajasthan         -8.695075
# West Bengal       -9.363630
# Maharashtra      -18.293357
# Name: gdp_growth_rate, dtype: float64

# %%
top_states = avg_growth_rate.head(5)

plt.figure(figsize=(10, 6))
m=sns.barplot(x=top_states.index, y=top_states.values, palette='viridis')
for container in m.containers:
  m.bar_label(container)
plt.title('Top 5 Performing States by Average GDP Growth Rate (2011-2023)')
plt.xlabel('State')
plt.ylabel('Average GDP Growth Rate (%)')
plt.xticks(rotation=45, ha='right')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-2612146190.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   m=sns.barplot(x=top_states.index, y=top_states.values, palette='viridis')

# %%
bottom_states = avg_growth_rate.tail(5)
plt.figure(figsize=(10, 6))
n=sns.barplot(x=bottom_states.index, y=bottom_states.values, palette='plasma')
plt.title('Bottom 5 Performing States by Average GDP Growth Rate (2011-2023)')
for container in n.containers:
    n.bar_label(container)
plt.xlabel('State')
plt.ylabel('Average GDP Growth Rate (%)')
plt.xticks(rotation=45, ha='right')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-4048300318.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   n=sns.barplot(x=bottom_states.index, y=bottom_states.values, palette='plasma')

# %%
df.corr(numeric_only=True)
# Out:
#                           year  gdp_per_capita  literacy_rate  \
# year                  1.000000       -0.109662      -0.044122
# gdp_per_capita       -0.109662        1.000000      -0.055364
# literacy_rate        -0.044122       -0.055364       1.000000
# female_literacy_rate  0.017985        0.009443      -0.067808
# poverty_rate          0.060416       -0.041274      -0.003339
# unemployment_rate    -0.006507        0.088067       0.043574
# internet_penetration -0.009583        0.069698       0.118894
# urban_population_pct -0.027002        0.032512      -0.058984
# life_expectancy      -0.036856       -0.102602      -0.008215
#
#                       female_literacy_rate  poverty_rate  unemployment_rate  \
# year                              0.017985      0.060416          -0.006507
# gdp_per_capita                    0.009443     -0.041274           0.088067
# literacy_rate                    -0.067808     -0.003339           0.043574
# ...

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %%
ab=df.groupby(["year"],as_index=False)[['literacy_rate',"poverty_rate"]].mean()
ab.head()
# Out:
#    year  literacy_rate  poverty_rate
# 0  2011      81.658549     29.187360
# 1  2012      81.618364     17.832967
# 2  2013      79.114762     20.034955
# 3  2014      85.886491     20.617113
# 4  2015      82.752760     22.077075

# %%
avg_literacy_rate = df.groupby('year')['literacy_rate'].mean()
avg_poverty_rate = df.groupby('year')['poverty_rate'].mean()
avg_literacy_rate.head()
# Out:
# year
# 2011    81.658549
# 2012    81.618364
# 2013    79.114762
# 2014    85.886491
# 2015    82.752760
# Name: literacy_rate, dtype: float64

# %%
avg_poverty_rate.head()
# Out:
# year
# 2011    29.187360
# 2012    17.832967
# 2013    20.034955
# 2014    20.617113
# 2015    22.077075
# Name: poverty_rate, dtype: float64

# %%
plt.figure(figsize=(15, 8))
plt.subplot(1, 2, 1)
plt.plot(avg_literacy_rate.index, avg_literacy_rate.values, marker='o', linestyle='-', color='skyblue', markersize=8)
plt.title('Average Literacy Rate Over Time', fontsize=14)
for x , y in zip(avg_literacy_rate.index, avg_literacy_rate.values):
  plt.text(x, y, f'{y:.2f}', ha='center', va='bottom', fontsize=10)
plt.xlabel('Year', fontsize=12)
plt.ylabel('Average Literacy Rate (%)', fontsize=12)
plt.grid(True, linestyle='--', alpha=0.7)
plt.xticks(rotation=45)

plt.subplot(1, 2, 2)
plt.plot(avg_poverty_rate.index, avg_poverty_rate.values, marker='o', linestyle='-', color='salmon', markersize=8)
plt.title('Average Poverty Rate Over Time', fontsize=14)
for x , y in zip(avg_poverty_rate.index, avg_poverty_rate.values):
  plt.text(x, y, f'{y:.2f}', ha='center', va='bottom', fontsize=10)
plt.xlabel('Year', fontsize=12)
plt.ylabel('Average Poverty Rate (%)', fontsize=12)
plt.grid(True, linestyle='--', alpha=0.7)
plt.xticks(rotation=45)

plt.tight_layout()
plt.show()

# %%
state_avg_data = df.groupby('state')[['literacy_rate', 'poverty_rate']].mean().reset_index()
state_avg_data_sorted = state_avg_data.sort_values(by='literacy_rate')


fig, ax1 = plt.subplots(figsize=(12, 7))

color = 'tab:blue'
ax1.set_xlabel('State (Sorted by Literacy Rate)')
ax1.set_ylabel('Literacy Rate (%)', color=color)
ax1.plot(state_avg_data_sorted['state'], state_avg_data_sorted['literacy_rate'], color=color, marker='o')
ax1.tick_params(axis='y', labelcolor=color)
ax1.set_xticks(range(len(state_avg_data_sorted['state'])))
ax1.set_xticklabels(state_avg_data_sorted['state'], rotation=45, ha='right')

ax2 = ax1.twinx()

color = 'tab:red'
ax2.set_ylabel('Poverty Rate (%)', color=color)
ax2.plot(state_avg_data_sorted['state'], state_avg_data_sorted['poverty_rate'], color=color, marker='o')
ax2.tick_params(axis='y', labelcolor=color)

plt.title(' the relationship between literacy and poverty ')
fig.tight_layout()
plt.show()

# %%
correlation_matrix = df.corr(numeric_only=True)
plt.figure(figsize=(12, 2))
sns.heatmap(correlation_matrix[['female_literacy_rate']].T, annot=True, cmap='coolwarm', fmt=".2f", linewidths=.5, annot_kws={"size": 10})
plt.title('Correlation of Female Literacy Rate with Other Indicators', fontsize=14)
plt.show()

# %%
uni=df.groupby(["year_by_phase","state"],as_index=False)["unemployment_rate"].mean()
uni.head()
# Out:
#   year_by_phase           state  unemployment_rate
# 0       Phase-1  Andhra Pradesh           9.133516
# 1       Phase-1           Bihar          10.157746
# 2       Phase-1           Delhi          10.005166
# 3       Phase-1         Gujarat           6.992046
# 4       Phase-1       Karnataka           7.524699

# %%
g = sns.relplot(data=uni, x="state", y="unemployment_rate", kind="line", col="year_by_phase",height=5, aspect=1.5,marker='o')
g.set_xticklabels(rotation=90, ha='right')
for ax in g.axes.flat:
    ax.set_title(f'Unemployment Rate in {ax.get_title()}')
    ax.grid(True, linestyle='--', alpha=0.7)
    for x_val, y_val in zip(ax.lines[0].get_xdata(), ax.lines[0].get_ydata()):
        ax.text(x_val, y_val, f'{y_val:.2f}', color='black', ha='center', va='bottom', fontsize=8)
g.set_axis_labels("State", "Average Unemployment Rate (%)")

plt.suptitle('Unemployment Rate by State Across Different Phases', y=1.02, fontsize=16)

plt.tight_layout(rect=[0, 0, 1, 0.98])
plt.show()

# %%
plt.figure(figsize=(18, 9))
ax = sns.lineplot(data=uni, x="state", y="unemployment_rate", hue="year_by_phase", marker='o', linewidth=2.5)
plt.title('Unemployment Rate by State Across Different Phases', fontsize=16)
plt.xlabel('State', fontsize=12)
plt.ylabel('Average Unemployment Rate (%)', fontsize=12)
plt.xticks(rotation=45, ha='right', fontsize=10)
plt.yticks(fontsize=10)
plt.grid(True, linestyle='--', alpha=0.7)
plt.legend(title='Year Phase', title_fontsize='13', fontsize='11', loc='upper left', bbox_to_anchor=(1, 1))

for line in ax.lines:
    for x, y in zip(line.get_xdata(), line.get_ydata()):
        ax.text(x, y, f'{y:.2f}', color=line.get_color(), ha='center', va='bottom', fontsize=8)
plt.tight_layout()
plt.show()

# %%
top_performace_state=top_states.head(1)
top_performace_state
# Out:
# state
# Delhi    14.169378
# Name: gdp_growth_rate, dtype: float64

# %%
bottom_performace_state=bottom_states.tail(1)
bottom_performace_state
# Out:
# state
# Maharashtra   -18.293357
# Name: gdp_growth_rate, dtype: float64

# %%
tp=df.groupby(["year","state"],as_index=False)["unemployment_rate"].mean()
top_state_name = top_performace_state.index[0]
bottom_state_name = bottom_performace_state.index[0]
tp=tp[tp["state"].isin([top_state_name,bottom_state_name])]
tp.head()
# Out:
#     year        state  unemployment_rate
# 2   2011        Delhi           9.851598
# 7   2011  Maharashtra          11.963573
# 14  2012        Delhi           7.156781
# 19  2012  Maharashtra           5.262206
# 26  2013        Delhi          11.992106

# %%
plt.figure(figsize=(18, 9))
ax = sns.lineplot(data=tp, x="year", y="unemployment_rate", hue="state", marker='o', linewidth=2.5)
plt.title('Unemployment Rate Trends for Delhi and Maharashtra (2011-2023)', fontsize=16)
plt.xlabel('Year', fontsize=12)
plt.ylabel('Average Unemployment Rate (%)', fontsize=12)
plt.xticks(tp['year'].unique(), rotation=45, ha='right', fontsize=10)
plt.yticks(fontsize=10)
plt.grid(True, linestyle='--', alpha=0.7)
plt.legend(title='State', title_fontsize='13', fontsize='11', loc='upper left', bbox_to_anchor=(1, 1))

for line in ax.lines:
    for x, y in zip(line.get_xdata(), line.get_ydata()):
        ax.text(x, y, f'{y:.2f}', color=line.get_color(), ha='center', va='bottom', fontsize=10)

plt.tight_layout()
plt.show()

# %%
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %%
correlation_sub = df[['internet_penetration', 'gdp_growth_rate']].corr()
plt.figure(figsize=(4, 3))
sns.heatmap(correlation_sub, annot=True, cmap='coolwarm', fmt=".2f", linewidths=.5)
plt.title('Correlation between Internet Penetration and GDP Growth Rate')
plt.show()

# %%
df['urban_population'] = pd.cut(df['urban_population_pct'], bins=4, labels=['Low Urban', 'Medium-Low Urban', 'Medium-High Urban', 'High Urban'])
j= df.groupby('urban_population')[['unemployment_rate', 'gdp_per_capita']].mean().reset_index()

fig, axes = plt.subplots(1, 2, figsize=(16, 6))
sns.lineplot(x='urban_population', y='unemployment_rate', data=j, ax=axes[0], marker='o', color='red')
axes[0].set_title('urbanization impact on employment')
axes[0].set_xlabel('Urban Population Levels')
axes[0].set_ylabel('Average Unemployment Rate (%)')
axes[0].grid(True, linestyle='--', alpha=0.7)

sns.lineplot(x='urban_population', y='gdp_per_capita', data=j, ax=axes[1], marker='o', color='green')
axes[1].set_title('urbanization impact on  income')
axes[1].set_xlabel('Urban Population Levels')
axes[1].set_ylabel('Average GDP Per Capita')
axes[1].grid(True, linestyle='--', alpha=0.7)

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-2553683531.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   j= df.groupby('urban_population')[['unemployment_rate', 'gdp_per_capita']].mean().reset_index()
